# %% [markdown]
# <a href="https://colab.research.google.com/github/AniketParasher/WorldCup2023_Data_Analysis_WebScraping_Python_PowerBi/blob/main/Data_Cleaning_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cleaning the match result table

# %%
import pandas as pd
df_m = pd.read_csv('/content/Matches_Table_Scraped_CSV.csv')

# %%
df_m.head()
# Out:
#       Team 1        Team 2     Winner     Margin        Ground    Match Date  \
# 0      India     Australia  Australia  6 wickets     Ahmedabad  Nov 19, 2023
# 1  Australia  South Africa  Australia  3 wickets  Eden Gardens  Nov 16, 2023
# 2      India   New Zealand      India    70 runs      Wankhede  Nov 15, 2023
# 3      India   Netherlands      India   160 runs     Bengaluru  Nov 12, 2023
# 4    England      Pakistan    England    93 runs  Eden Gardens  Nov 11, 2023
#
#     Scorecard
# 0  ODI # 4705
# 1  ODI # 4704
# 2  ODI # 4703
# 3  ODI # 4702
# 4  ODI # 4701

# %%
df_m.shape
# Out:
# (48, 7)

# %% [markdown]
# To check if we any null values in the dataframe

# %%
df_m.isnull().sum()
# Out:
# Team 1        0
# Team 2        0
# Winner        0
# Margin        0
# Ground        0
# Match Date    0
# Scorecard     0
# dtype: int64

# %% [markdown]
# Wanted to treat this score card as primary key to have it linked with other table. Renaming it to match_id

# %%
df_m.rename({'Scorecard' : 'match_id'}, axis=1, inplace=True)

# %%
df_m.head()
# Out:
#       Team 1        Team 2     Winner     Margin        Ground    Match Date  \
# 0      India     Australia  Australia  6 wickets     Ahmedabad  Nov 19, 2023
# 1  Australia  South Africa  Australia  3 wickets  Eden Gardens  Nov 16, 2023
# 2      India   New Zealand      India    70 runs      Wankhede  Nov 15, 2023
# 3      India   Netherlands      India   160 runs     Bengaluru  Nov 12, 2023
# 4    England      Pakistan    England    93 runs  Eden Gardens  Nov 11, 2023
#
#      match_id
# 0  ODI # 4705
# 1  ODI # 4704
# 2  ODI # 4703
# 3  ODI # 4702
# 4  ODI # 4701

# %%
df_m.to_csv('Match_result_transformed_CSV.csv')

# %% [markdown]
# I want to use this match_id and add in batting and bowling data to link them in Power BI. To do that create a dictionary from this table and map it to match in batting table

# %%
match_ids_dict = {}

for index, row in df_m.iterrows():
  key1 = row['Team 1'] + ' Vs ' + row['Team 2']
  key2 = row['Team 2'] + ' Vs ' + row['Team 1']

  match_ids_dict[key1] = row['match_id']
  match_ids_dict[key2] = row['match_id']

match_ids_dict
# Out:
# {'India Vs Australia': 'ODI # 4662',
#  'Australia Vs India': 'ODI # 4662',
#  'Australia Vs South Africa': 'ODI # 4667',
#  'South Africa Vs Australia': 'ODI # 4667',
#  'India Vs New Zealand': 'ODI # 4678',
#  'New Zealand Vs India': 'ODI # 4678',
#  'India Vs Netherlands': 'ODI # 4702',
#  'Netherlands Vs India': 'ODI # 4702',
#  'England Vs Pakistan': 'ODI # 4701',
#  'Pakistan Vs England': 'ODI # 4701',
#  'Australia Vs Bangladesh': 'ODI # 4700',
#  'Bangladesh Vs Australia': 'ODI # 4700',
#  'Afghanistan Vs South Africa': 'ODI # 4699',
#  'South Africa Vs Afghanistan': 'ODI # 4699',
#  'New Zealand Vs Sri Lanka': 'ODI # 4698',
#  'Sri Lanka Vs New Zealand': 'ODI # 4698',
#  'England Vs Netherlands': 'ODI # 4697',
#  'Netherlands Vs England': 'ODI # 4697',
#  'Afghanistan Vs Australia': 'ODI # 4696',
#  'Australia Vs Afghanistan': 'ODI # 4696',
#  'Bangladesh Vs Sri Lanka': 'ODI # 4695',
#  'Sri Lanka Vs Bangladesh': 'ODI # 4695',
#  'India Vs South Africa': 'ODI # 4694',
#  'South Africa Vs India': 'ODI # 4694',
#  'Australia Vs England': 'ODI # 4693',
#  'England Vs Australia': 'ODI # 4693',
#  'New Zealand Vs Pakistan': 'ODI # 4692',
#  'Pakistan Vs New Zealand': 'ODI # 4692',
#  'Afghanistan Vs Netherlands': 'ODI # 4691',
#  'Netherlands Vs Afghanistan': 'ODI # 4691',
#  'India Vs Sri Lanka': 'ODI # 4690',
#  'Sri Lanka Vs India': 'ODI # 4690',
#  'New Zealand Vs South Africa': 'ODI # 4689',
#  'South Africa Vs New Zealand': 'ODI # 4689',
#  'Bangladesh Vs Pakistan': 'ODI # 4688',
#  'Pakistan Vs Bangladesh': 'ODI # 4688',
#  'Afghanistan Vs Sri Lanka': 'ODI # 4687',
#  'Sri Lanka Vs Afghanistan': 'ODI # 4687',
#  'India Vs England': 'ODI # 4686',
#  'England Vs India': 'ODI # 4686',
#  'Bangladesh Vs Netherlands': 'ODI # 4685',
#  'Netherlands Vs Bangladesh': 'ODI # 4685',
#  'Australia Vs New Zealand': 'ODI # 4684',
#  'New Zealand Vs Australia': 'ODI # 4684',
#  'Pakistan Vs South Africa': 'ODI # 4683',
#  'South Africa Vs Pakistan': 'ODI # 4683',
#  'England Vs Sri Lanka': 'ODI # 4682',
#  'Sri Lanka Vs England': 'ODI # 4682',
#  'Australia Vs Netherlands': 'ODI # 4681',
#  'Netherlands Vs Australia': 'ODI # 4681',
#  'Bangladesh Vs South Africa': 'ODI # 4680',
#  'South Africa Vs Bangladesh': 'ODI # 4680',
#  'Afghanistan Vs Pakistan': 'ODI # 4679',
#  'Pakistan Vs Afghanistan': 'ODI # 4679',
#  'England Vs South Africa': 'ODI # 4677',
#  'South Africa Vs England': 'ODI # 4677',
#  'Netherlands Vs Sri Lanka': 'ODI # 4676',
#  'Sri Lanka Vs Netherlands': 'ODI # 4676',
#  'Australia Vs Pakistan': 'ODI # 4675',
#  'Pakistan Vs Australia': 'ODI # 4675',
#  'India Vs Bangladesh': 'ODI # 4674',
#  'Bangladesh Vs India': 'ODI # 4674',
#  'Afghanistan Vs New Zealand': 'ODI # 4673',
#  'New Zealand Vs Afghanistan': 'ODI # 4673',
#  'Netherlands Vs South Africa': 'ODI # 4672',
#  'South Africa Vs Netherlands': 'ODI # 4672',
#  'Australia Vs Sri Lanka': 'ODI # 4671',
#  'Sri Lanka Vs Australia': 'ODI # 4671',
#  'Afghanistan Vs England': 'ODI # 4670',
#  'England Vs Afghanistan': 'ODI # 4670',
#  'India Vs Pakistan': 'ODI # 4669',
#  'Pakistan Vs India': 'ODI # 4669',
#  'Bangladesh Vs New Zealand': 'ODI # 4668',
#  'New Zealand Vs Bangladesh': 'ODI # 4668',
#  'India Vs Afghanistan': 'ODI # 4666',
#  'Afghanistan Vs India': 'ODI # 4666',
#  'Pakistan Vs Sri Lanka': 'ODI # 4665',
#  'Sri Lanka Vs Pakistan': 'ODI # 4665',
#  'Bangladesh Vs England': 'ODI # 4664',
#  'England Vs Bangladesh': 'ODI # 4664',
#  'Netherlands Vs New Zealand': 'ODI # 4663',
#  'New Zealand Vs Netherlands': 'ODI # 4663',
#  'South Africa Vs Sri Lanka': 'ODI # 4661',
#  'Sri Lanka Vs South Africa': 'ODI # 4661',
#  'Afghanistan Vs Bangladesh': 'ODI # 4660',
#  'Bangladesh Vs Afghanistan': 'ODI # 4660',
#  'Netherlands Vs Pakistan': 'ODI # 4659',
#  'Pakistan Vs Netherlands': 'ODI # 4659',
#  'England Vs New Zealand': 'ODI # 4658',
#  'New Zealand Vs England': 'ODI # 4658'}

# %% [markdown]
# Lets make data cleaning and transformation in batting data

# %%
df_bat = pd.read_csv('/content/batting_data_scraped_CSV (1).csv')

# %%
df_bat
# Out:
#                       match  teaminnings  battingPos           BATTING  \
# 0        India Vs Australia        India           1  Rohit Sharma (c)
# 1        India Vs Australia        India           2      Shubman Gill
# 2        India Vs Australia        India           3       Virat Kohli
# 3        India Vs Australia        India           4      Shreyas Iyer
# 4        India Vs Australia        India           5        KL Rahul †
# ..                      ...          ...         ...               ...
# 871  England Vs New Zealand      England          10       Adil Rashid
# 872  England Vs New Zealand      England          11         Mark Wood
# 873  England Vs New Zealand  New Zealand           1      Devon Conway
# 874  England Vs New Zealand  New Zealand           2        Will Young
# 875  England Vs New Zealand  New Zealand           3   Rachin Ravindra
#
#                dismissal    R    B    M  4s 6s      SR
# 0       c Head b Maxwell   47   31   44   4  3  151.61
# 1        c Zampa b Starc    4    7   21   0  0   57.14
# 2              b Cummins   54   63   99   4  0   85.71
# 3    c †Inglis b Cummins    4    3    3   1  0  133.33
# 4      c †Inglis b Starc   66  107  133   1  0   61.68
# ..                   ...  ...  ...  ...  .. ..     ...
# 871              not out   15   13   23   0  1  115.38
# 872              not out   13   14   19   0  0   92.85
# 873              not out  152  121  147  19  3  125.61
# 874  c †Buttler b Curran    0    1    5   0  0    0.00
# 875              not out  123   96  141  11  5  128.12
#
# [876 rows x 11 columns]

# %% [markdown]
# I want to make dimissal column as categorical with out and not out data

# %%
df_bat['out/not_out'] = df_bat.dismissal.apply(lambda x: "not_out" if x == "not out" else "out")

# %%
df_bat.head()
# Out:
#                 match teaminnings  battingPos           BATTING  \
# 0  India Vs Australia       India           1  Rohit Sharma (c)
# 1  India Vs Australia       India           2      Shubman Gill
# 2  India Vs Australia       India           3       Virat Kohli
# 3  India Vs Australia       India           4      Shreyas Iyer
# 4  India Vs Australia       India           5        KL Rahul †
#
#              dismissal   R    B    M 4s 6s      SR out/not_out
# 0     c Head b Maxwell  47   31   44  4  3  151.61         out
# 1      c Zampa b Starc   4    7   21  0  0   57.14         out
# 2            b Cummins  54   63   99  4  0   85.71         out
# 3  c †Inglis b Cummins   4    3    3  1  0  133.33         out
# 4    c †Inglis b Starc  66  107  133  1  0   61.68         out

# %% [markdown]
# drop the dismissal column

# %%
df_bat.drop(columns=['dismissal'], inplace=True)
df_bat.head()
# Out:
#                 match teaminnings  battingPos           BATTING   R    B    M  \
# 0  India Vs Australia       India           1  Rohit Sharma (c)  47   31   44
# 1  India Vs Australia       India           2      Shubman Gill   4    7   21
# 2  India Vs Australia       India           3       Virat Kohli  54   63   99
# 3  India Vs Australia       India           4      Shreyas Iyer   4    3    3
# 4  India Vs Australia       India           5        KL Rahul †  66  107  133
#
#   4s 6s      SR out/not_out
# 0  4  3  151.61         out
# 1  0  0   57.14         out
# 2  4  0   85.71         out
# 3  1  0  133.33         out
# 4  1  0   61.68         out

# %% [markdown]
# Clean batting column containing special character

# %%
df_bat["BATTING"] = df_bat["BATTING"].apply(lambda x: x.replace("(c)", ""))

# %%
df_bat["BATTING"] = df_bat["BATTING"].apply(lambda x: x.replace("†", ""))
df_bat["BATTING"] = df_bat["BATTING"].apply(lambda x: x.replace("€", ""))
df_bat["BATTING"] = df_bat["BATTING"].apply(lambda x: x.replace("Â", ""))
df_bat["BATTING"] = df_bat["BATTING"].apply(lambda x: x.replace("â", ""))

# %%
df_bat.head()
# Out:
#                 match teaminnings  battingPos        BATTING   R    B    M 4s  \
# 0  India Vs Australia       India           1  Rohit Sharma   47   31   44  4
# 1  India Vs Australia       India           2   Shubman Gill   4    7   21  0
# 2  India Vs Australia       India           3    Virat Kohli  54   63   99  4
# 3  India Vs Australia       India           4   Shreyas Iyer   4    3    3  1
# 4  India Vs Australia       India           5      KL Rahul   66  107  133  1
#
#   6s      SR out/not_out
# 0  3  151.61         out
# 1  0   57.14         out
# 2  0   85.71         out
# 3  0  133.33         out
# 4  0   61.68         out

# %%
df_bat['match_id'] = df_bat['match'].map(match_ids_dict)

# %%
df_bat.head()
# Out:
#                 match teaminnings  battingPos        BATTING   R    B    M 4s  \
# 0  India Vs Australia       India           1  Rohit Sharma   47   31   44  4
# 1  India Vs Australia       India           2   Shubman Gill   4    7   21  0
# 2  India Vs Australia       India           3    Virat Kohli  54   63   99  4
# 3  India Vs Australia       India           4   Shreyas Iyer   4    3    3  1
# 4  India Vs Australia       India           5      KL Rahul   66  107  133  1
#
#   6s      SR out/not_out    match_id
# 0  3  151.61         out  ODI # 4662
# 1  0   57.14         out  ODI # 4662
# 2  0   85.71         out  ODI # 4662
# 3  0  133.33         out  ODI # 4662
# 4  0   61.68         out  ODI # 4662

# %%
df_bat.to_csv("batting_transformed_csv.csv")

# %% [markdown]
# Same match id to be added in bowling column

# %%
df_bowl = pd.read_csv('/content/bowling_data_Scraped_CSV.csv')

# %%
df_bowl.head()
# Out:
#                 match bowlingTeam      bowlerName     O  M   R  W  ECON  0s  \
# 0  India Vs Australia   Australia  Mitchell Starc  10.0  0  55  3  5.50  30
# 1  India Vs Australia   Australia  Josh Hazlewood  10.0  0  60  2  6.00  22
# 2  India Vs Australia   Australia   Glenn Maxwell   6.0  0  35  1  5.83  19
# 3  India Vs Australia   Australia     Pat Cummins  10.0  0  34  2  3.40  30
# 4  India Vs Australia   Australia      Adam Zampa  10.0  0  44  1  4.40  22
#
#    4s  6s  WD  NB
# 0   4   1   3   0
# 1   4   1   1   0
# 2   4   1   0   0
# 3   0   0   2   0
# 4   1   0   1   0

# %%
df_bowl['match_id'] = df_bowl['match'].map(match_ids_dict)

# %%
df_bowl
# Out:
#                       match bowlingTeam        bowlerName     O  M   R  W  \
# 0        India Vs Australia   Australia    Mitchell Starc  10.0  0  55  3
# 1        India Vs Australia   Australia    Josh Hazlewood  10.0  0  60  2
# 2        India Vs Australia   Australia     Glenn Maxwell   6.0  0  35  1
# 3        India Vs Australia   Australia       Pat Cummins  10.0  0  34  2
# 4        India Vs Australia   Australia        Adam Zampa  10.0  0  44  1
# ..                      ...         ...               ...   ... ..  .. ..
# 569  England Vs New Zealand     England        Sam Curran   6.0  2  47  1
# 570  England Vs New Zealand     England         Mark Wood   5.0  0  55  0
# 571  England Vs New Zealand     England         Moeen Ali   9.2  0  60  0
# 572  England Vs New Zealand     England       Adil Rashid   7.0  0  47  0
# 573  England Vs New Zealand     England  Liam Livingstone   3.0  0  24  0
#
#       ECON  0s  4s  6s  WD  NB    match_id
# 0     5.50  30   4   1   3   0  ODI # 4662
# 1     6.00  22   4   1   1   0  ODI # 4662
# 2     5.83  19   4   1   0   0  ODI # 4662
# 3     3.40  30   0   0   2   0  ODI # 4662
# 4     4.40  22   1   0   1   0  ODI # 4662
# ..     ...  ..  ..  ..  ..  ..         ...
# 569   7.83  17   6   1   2   0  ODI # 4658
# 570  11.00   9   7   2   1   0  ODI # 4658
# 571   6.42  20   2   3   0   0  ODI # 4658
# 572   6.71  15   4   1   0   0  ODI # 4658
# 573   8.00   7   4   0   0   0  ODI # 4658
#
# [574 rows x 14 columns]

# %%
df_bowl.to_csv("bowling_transformed_CSV.csv")
